# %%
import urllib2
import re
import re
from bs4 import BeautifulSoup
import json
import datetime
from dateutil.parser import parse
from bs4.element import Comment
import pandas as pd
import collections

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

def get_ascii_only(string):
    return ''.join([i if ord(i) < 128 else '' for i in string])
    

def text_from_html(body):
    # soup = BeautifulSoup(body, 'html.parser')
    try:
        texts = body.findAll(text=True)
        visible_texts = filter(tag_visible, texts)  
        return u" ".join(t.strip() for t in visible_texts)
    except:
        return ""

def parse_data_save(links):
    d_title = collections.defaultdict(int)
    result = []
    for title, link in links:
        if title in ("If you are interested in editing this book", "If you have questions related to Java"):
            continue
        page = urllib2.urlopen(link)
        soup = BeautifulSoup(page)
        text = ""
        t = ""
        for tag in content:
            if tag.name == 'table':
                continue
            if tag.name in ('h1','h2', 'h3', 'h4', 'h5'):
                d = {}
                d["url"] = link
                titt = title + " " + t
                titt = titt.replace("[edit]", "")
                d['title'] = titt
                d['text'] = text
                if text:
                    result.append(d)
                text = ""
                t = tag.text
            else:
                text += get_ascii_only(text_from_html(tag).strip())
    df = pd.DataFrame(result)
    df.to_csv('data.csv')
    return df

def remove_spaces(text):
    return re.sub('\s+',' ',text)

def get_all_wikibooks_links(wikibooks_url):
    page = urllib2.urlopen(wikibooks_url)
    soup = BeautifulSoup(page)
    main_div = soup.find('div', class_="mw-content-ltr")
    ul = main_div.find_all('ul')
    domain = "https://en.wikibooks.org/%s"
    links = []
    for u in ul:
        li = u.find_all('li')
        for l in li:
            a_tag = l.find('a', recursive=False)
            if a_tag: 
                link_text = a_tag.text
                link = domain%a_tag.get('href')
                links.append((link_text, link))
    return links
    

wikibooks_url = 'https://en.wikibooks.org/wiki/Java_Programming'
df = parse_data_save(get_all_wikibooks_links(wikibooks_url))

# %%
df
# Out:
#                                                   text  \
# 0    We conceptualize the world around us in terms ...
# 1    Programming is essentially thinking of solutio...
# 2    In OOP, every abstraction of a real-life objec...
# 3    Aristotle was perhaps the first person to thin...
# 4    Although each object you create from a class d...
# 5    At this point, your objects do nothing more th...
# 6    By now, we thoroughly understand that any obje...
# 7    We conceptualize the world around us in terms ...
# 8    Programming is essentially thinking of solutio...
# 9    In OOP, every abstraction of a real-life objec...
# 10   Aristotle was perhaps the first person to thin...
# 11   Although each object you create from a class d...
# 12   At this point, your objects do nothing more th...
# 13   By now, we thoroughly understand that any obje...
# 14   We conceptualize the world around us in terms ...
# 15   Programming is essentially thinking of solutio...
# 16   In OOP, every abstraction of a real-life objec...
# 17   Aristotle was perhaps the first person to thin...
# 18   Although each object you create from a class d...
# 19   At this point, your objects do nothing more th...
# 20   By now, we thoroughly understand that any obje...
# 21   We conceptualize the world around us in terms ...
# 22   Programming is essentially thinking of solutio...
# 23   In OOP, every abstraction of a real-life objec...
# 24   Aristotle was perhaps the first person to thin...
# 25   Although each object you create from a class d...
# 26   At this point, your objects do nothing more th...
# 27   By now, we thoroughly understand that any obje...
# 28   We conceptualize the world around us in terms ...
# 29   Programming is essentially thinking of solutio...
# ..                                                 ...
# 635  At this point, your objects do nothing more th...
# 636  By now, we thoroughly understand that any obje...
# 637  We conceptualize the world around us in terms ...
# 638  Programming is essentially thinking of solutio...
# 639  In OOP, every abstraction of a real-life objec...
# 640  Aristotle was perhaps the first person to thin...
# 641  Although each object you create from a class d...
# 642  At this point, your objects do nothing more th...
# 643  By now, we thoroughly understand that any obje...
# 644  We conceptualize the world around us in terms ...
# 645  Programming is essentially thinking of solutio...
# 646  In OOP, every abstraction of a real-life objec...
# 647  Aristotle was perhaps the first person to thin...
# 648  Although each object you create from a class d...
# 649  At this point, your objects do nothing more th...
# 650  By now, we thoroughly understand that any obje...
# 651  We conceptualize the world around us in terms ...
# 652  Programming is essentially thinking of solutio...
# 653  In OOP, every abstraction of a real-life objec...
# 654  Aristotle was perhaps the first person to thin...
# 655  Although each object you create from a class d...
# 656  At this point, your objects do nothing more th...
# 657  By now, we thoroughly understand that any obje...
# 658  We conceptualize the world around us in terms ...
# 659  Programming is essentially thinking of solutio...
# 660  In OOP, every abstraction of a real-life objec...
# 661  Aristotle was perhaps the first person to thin...
# 662  Although each object you create from a class d...
# 663  At this point, your objects do nothing more th...
# 664  By now, we thoroughly understand that any obje...
#
#                                                  title  \
# 0                 Recent changes Understanding systems
# 1            Recent changes The process of abstraction
# 2                   Recent changes Thinking in objects
# 3    Recent changes Understanding class definitions...
# 4      Recent changes Expanding your class definitions
# 5            Recent changes Adding behavior to objects
# 6          Recent changes The process of encapsulation
# 7      How to format the content Understanding systems
# 8    How to format the content The process of abstr...
# 9        How to format the content Thinking in objects
# 10   How to format the content Understanding class ...
# 11   How to format the content Expanding your class...
# 12   How to format the content Adding behavior to o...
# 13   How to format the content The process of encap...
# 14           Who is contributing Understanding systems
# 15      Who is contributing The process of abstraction
# 16             Who is contributing Thinking in objects
# 17   Who is contributing Understanding class defini...
# 18   Who is contributing Expanding your class defin...
# 19      Who is contributing Adding behavior to objects
# 20    Who is contributing The process of encapsulation
# 21               About this book Understanding systems
# 22          About this book The process of abstraction
# 23                 About this book Thinking in objects
# 24   About this book Understanding class definition...
# 25    About this book Expanding your class definitions
# 26          About this book Adding behavior to objects
# 27        About this book The process of encapsulation
# 28               History of Java Understanding systems
# 29          History of Java The process of abstraction
# ..                                                 ...
# 635              Invoking C Adding behavior to objects
# 636            Invoking C The process of encapsulation
# 637                    Byte Code Understanding systems
# 638               Byte Code The process of abstraction
# 639                      Byte Code Thinking in objects
# 640  Byte Code Understanding class definitions and ...
# 641         Byte Code Expanding your class definitions
# 642               Byte Code Adding behavior to objects
# 643             Byte Code The process of encapsulation
# 644                        Links Understanding systems
# 645                   Links The process of abstraction
# 646                          Links Thinking in objects
# 647    Links Understanding class definitions and types
# 648             Links Expanding your class definitions
# 649                   Links Adding behavior to objects
# 650                 Links The process of encapsulation
# 651                     Glossary Understanding systems
# 652                Glossary The process of abstraction
# 653                       Glossary Thinking in objects
# 654  Glossary Understanding class definitions and t...
# 655          Glossary Expanding your class definitions
# 656                Glossary Adding behavior to objects
# 657              Glossary The process of encapsulation
# 658                        Index Understanding systems
# 659                   Index The process of abstraction
# 660                          Index Thinking in objects
# 661    Index Understanding class definitions and types
# 662             Index Expanding your class definitions
# 663                   Index Adding behavior to objects
# 664                 Index The process of encapsulation
#
#                                                    url
# 0    https://en.wikibooks.org//wiki/Special:RecentC...
# 1    https://en.wikibooks.org//wiki/Special:RecentC...
# 2    https://en.wikibooks.org//wiki/Special:RecentC...
# 3    https://en.wikibooks.org//wiki/Special:RecentC...
