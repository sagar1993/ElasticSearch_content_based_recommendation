# %%
import urllib2
import re
import re
from bs4 import BeautifulSoup
import json
import datetime
from dateutil.parser import parse
from bs4.element import Comment
import pandas as pd

# %%
oracle_url = 'https://docs.oracle.com/javase/tutorial/'

# %%
def remove_spaces(text):
    return re.sub('\s+',' ',text)

# %%
page = urllib2.urlopen(oracle_url)
soup = BeautifulSoup(page)

# %%
ul = soup.find_all('ul', class_="BlueArrows")

# %%
domain = "https://docs.oracle.com/javase/tutorial/%s"
links = []
for u in ul:
    li = u.find_all('li')
    for l in li:
        a_tag = l.find('a')
        if a_tag:
            href = a_tag.get('href')
            if 'http' in href:
                links.append(href)
            else:
                links.append(domain%href)

# %%
links

all_links = [(link, 0) for link in links]

# %%
all_links
# Out:
# [('https://docs.oracle.com/javase/tutorial/getStarted/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/java/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/essential/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/collections/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/datetime/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/deployment/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/extra/certification/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/uiswing/index.html', 0),
#  ('https://docs.oracle.com/javafx/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/networking/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/ext/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/extra/fullscreen/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/extra/generics/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/i18n/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/javabeans/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/jdbc/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/jmx/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/jndi/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/jaxp/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/jaxb/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/rmi/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/reflect/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/security/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/sound/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/2d/index.html', 0),
#  ('https://docs.oracle.com/javase/tutorial/sdp/index.html', 0)]

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

url_list = []
url_list.extend(all_links)

result = []
domain = "https://docs.oracle.com/javase/tutorial/%s"
url_set = set()
while url_list:
    url, depth = url_list.pop()
    url_set.add(url)
    if depth > 6:
        continue
        
    print(url, depth)
    
    try:
        page = urllib2.urlopen(url)
    except:
        continue

    soup = BeautifulSoup(page)
    body = soup.find('div', {"id":"PageContent"})
    if body:
        d = {}
        d["url"] = url
        d["text"] = text_from_html(str(body)).encode('utf-8').strip()
        result.append(d)

        a_tags = body.find_all('a')
        for tag in a_tags:
            href = tag.get('href')
            if not href:
                continue
            if 'http' in href:
                href_url = href
            else:
                href_url = url.replace('index.html', href)
            if href_url not in url_set and 'docs.oracle.com' in href_url:
                url_list.append((href_url, depth+1))
# Out:
# ('https://docs.oracle.com/javase/tutorial/sdp/index.html', 0)
# ('https://docs.oracle.com/javase/tutorial/2d/index.html', 0)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/user.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/2d/spec/j2d-bookTOC.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/font/TextLayout.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Shape.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Graphics2D.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/complexshapes.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/Area.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/quality.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/RenderingHints.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/compositing.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/AlphaComposite.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/clipping.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/font/TextLayout.html#getOutline-java.awt.geom.AffineTransform-', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/advanced/transforming.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/AffineTransform.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/swing.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/text/JTextComponent.html#print--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JTable.html#print--', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/gui.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/services.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/jps/spec/JPSTOC.fm.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/print/attribute/standard/package-frame.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/print/attribute/package-frame.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/print/DocFlavor.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/print/package-summary.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/set.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/FontMetrics.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Point.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/Printable.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/dialog.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/PageFormat.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/PrinterJob.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/PrinterJob.html#printDialog--', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/printing/../printing/printable.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Graphics.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/package-summary.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/print/package-frame.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/print/package-frame.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/images/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/images/saveimage.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/imageio/spec/title.fm.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/images/drawonimage.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/images/drawimage.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/image/BufferedImage.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/images/loadimage.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/image/BufferedImage.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Image.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/images/../overview/images.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/text/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/text/advanced.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/font/package-summary.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/package-summary.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/text/measuringtext.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Font.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/text/fonts.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/intl/fontconfig.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/geometry/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/geometry/strokeandfill.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/Stroke.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/geometry/arbitrary.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/GeneralPath.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/geometry/primitives.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/package-summary.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/Arc2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/Ellipse2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/RoundRectangle2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/Rectangle2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/CubicCurve2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/QuadCurve2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/Line2D.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/PathIterator.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/awt/geom/package-frame.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/examples/images/weather-sun.png', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/examples/images/weather-snow.png', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/examples/images/weather-rain.png', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/examples/images/weather-cloud.png', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/examples/WeatherWizard.java', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../../uiswing/components/slider.html', 2)
# ('https://docs.oracle.com/javase/8/javafx/user-interface-tutorial/slider.htm', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getModel--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setModel-javax.swing.BoundedRangeModel-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/DefaultBoundedRangeModel.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/BoundedRangeModel.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getValueIsAdjusting--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#addChangeListener-javax.swing.event.ChangeListener-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setFont-java.awt.Font-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#createStandardLabels-int-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#createStandardLabels-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getLabelTable--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setLabelTable-java.util.Dictionary-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getPaintLabels--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setPaintLabels-boolean-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getPaintTicks--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setPaintTicks-boolean-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getMinorTickSpacing--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setMinorTickSpacing-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getMajorTickSpacing--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setMajorTickSpacing-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getMaximum--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setMaximum-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getMinimum--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setMinimum-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getInverted--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setInverted-boolean-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getOrientation--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setOrientation-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#getValue--', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#setValue-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider-javax.swing.BoundedRangeModel-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider-int-int-int-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider-int-int-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider-int-int-', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html#JSlider--', 3)
# ('https://docs.oracle.com/javase/tutorialJWS/samples/uiswing/SliderDemo2Project/SliderDemo2.jnlp', 3)
# ('https://docs.oracle.com/javase/tutorialJWS/samples/uiswing/SliderDemoProject/SliderDemo.jnlp', 3)
# ('https://docs.oracle.com/javase/8/docs/api/javax/swing/JSlider.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../overview/coordinate.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/index.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/user.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/complexshapes.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/quality.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/compositing.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/clipping.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/basic2d/../advanced/transforming.html', 3)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/printing.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/images.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/text.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/primitives.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/rendering.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/coordinate.html', 2)
# ('https://docs.oracle.com/javase/tutorial/2d/overview/coordinate.html', 2)
# ('https://docs.oracle.com/javase/tutorial/sound/index.html', 0)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/midi/MidiSystem.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/sampled/AudioSystem.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/midi/spi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/sampled/spi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/midi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/sampled/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/midi/spi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/sampled/spi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/midi/package-summary.html', 1)
# ('https://docs.oracle.com/javase/8/docs/api/javax/sound/sampled/package-summary.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/index.html', 0)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/security/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/together.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/policy.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/security/PolicyFiles.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/perm.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/highscore.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./userperm/game.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/enhancements.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/versig.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/gensig.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/index.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/tools/unix/keytool.html', 3)
# ('https://docs.oracle.com/javase/8/docs/technotes/tools/windows/keytool.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/#ImportReply', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/sender.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/security/SecurityToolsSummary.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/signer.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/enhancements.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/versig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/gensig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../../deployment/jar/signing.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/#Tools', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/#API', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/#Notes', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/#Intro', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../apisign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./apisign/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/receiver.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/sender.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/index.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/#ImportReply', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/sender.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/signer.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/enhancements.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/versig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/gensig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../../deployment/jar/signing.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/#Tools', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/#API', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/#Notes', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/#Intro', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../apisign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolfilex/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/receiver.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/signer.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/index.html', 2)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/#ImportReply', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/sender.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/receiver.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/signer.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolfilex/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../toolsign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/enhancements.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/versig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/gensig.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../apisign/../sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/../../deployment/jar/signing.html', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/#Tools', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/#API', 3)
# ('https://docs.oracle.com/javase/tutorial/security/./toolsign/../sigcert/#Notes', 3)
# ...
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/#ImportReply', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/sender.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/receiver.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/signer.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/enhancements.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/versig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/gensig.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/../sigcert/index.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../../deployment/jar/signing.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/#Tools', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/#API', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/#Notes', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/#Intro', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../apisign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolfilex/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./sigcert/../toolsign/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/step4.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/step3.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/step2.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/step1.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/../tour1/index.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour2/../tour1/step2.html', 6)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour1/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/./tour1/step2.html', 5)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../security/../deployment/applet/index.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/../essential/environment/security.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/cookies/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/cookies/custom.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/cookies/cookiemanager.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/cookies/cookiehandler.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/cookies/definition.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/nifs/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/nifs/parameters.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/nifs/listing.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/nifs/retrieving.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/nifs/definition.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/datagrams/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/datagrams/broadcasting.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/datagrams/clientServer.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/datagrams/definition.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/sockets/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/sockets/clientServer.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/sockets/readingWriting.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/sockets/definition.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/readingWriting.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/connecting.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/readingURL.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/urlInfo.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/creatingUrls.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/urls/definition.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/overview/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/overview/networking.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/../../networking/overview/alreadyknow.html', 4)
# ('https://docs.oracle.com/javase/tutorial/essential/io/QandE/questions.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/summary.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/legacy.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/misc.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/notification.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/find.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/walk.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/links.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/dirs.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/rafs.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/file.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/fileAttr.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/move.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/copy.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/delete.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/check.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/fileOps.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/pathOps.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/pathClass.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/path.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/fileio.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/objectstreams.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/datastreams.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/cl.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/scanfor.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/buffers.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/charstreams.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/bytestreams.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/io/streams.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/QandE/questions.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/summary.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/advantages.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/runtime.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/tryResourceClose.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/throwing.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/catchOrDeclare.html', 2)
# ('https://docs.oracle.com/javase/tutorial/essential/exceptions/definition.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/index.html', 0)
# ('https://docs.oracle.com/javase/tutorial/java/package/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/generics/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/index.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/acknowledgements.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/convert.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/morefun.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/literals.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/fineprint.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/legacy.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/methods.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/wildcards.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/subtype.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/simple.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/generics/../../extra/generics/intro.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/data/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/data/strings.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/data/numbers.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/java/lang/Math.html', 3)
# ('https://docs.oracle.com/javase/8/docs/api/java/lang/Number.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/IandI/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/IandI/subclasses.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/IandI/createinterface.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/annotations/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/enum.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/nested.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/more.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/objects.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/javaOO/classes.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/nutsandbolts/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/nutsandbolts/flow.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/nutsandbolts/expressions.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/nutsandbolts/operators.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/nutsandbolts/variables.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/QandE/questions.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/package.html', 2)
# ('https://docs.oracle.com/javase/8/docs/api/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/interface.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/inheritance.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/class.html', 2)
# ('https://docs.oracle.com/javase/tutorial/java/concepts/object.html', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/index.html', 0)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/../application/index.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/javadoc/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/../application/#MAIN', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/../application/#CLASS_DEF', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/../application/#COMMENTS', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/problems/../application/index.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/install/windows_jdk_install.html#BABGDJFH', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/install/windows_jdk_install.html#BABGDJFH', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/application/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/getStarted/application/#MAIN', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/application/#CLASS_DEF', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/application/#COMMENTS', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/index.html', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/../application/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/../application/#MAIN', 4)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/../application/#CLASS_DEF', 4)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/../application/#COMMENTS', 4)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/../problems/../application/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/unix.html', 2)
# ('https://docs.oracle.com/javase/8/docs/technotes/guides/install/install_overview.html', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/win32.html', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/cupojava/netbeans.html', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/intro/index.html', 1)
# ('https://docs.oracle.com/javase/tutorial/getStarted/intro/changemylife.html', 2)
# ('https://docs.oracle.com/javase/tutorial/getStarted/intro/cando.html', 2)
# ('https://docs.oracle.com/javase/8/docs/index.html', 3)
# ('https://docs.oracle.com/javase/tutorial/getStarted/intro/definition.html', 2)

# %%
len(result)
# Out:
# 2551

# %%
df = pd.DataFrame(result)

# %%
df.head()
# Out:
#                                                 text  \
# 0  The Sockets Direct Protocol (SDP) provides acc...
# 1  This trail introduces you to the Java 2Dâ„¢ AP...
# 2  This lesson shows you how to use Graphics2D to...
# 3  To enable the user to interact with the graphi...
# 4  Constructive area geometry (CAG) is the proces...
#
#                                                  url
# 0  https://docs.oracle.com/javase/tutorial/sdp/in...
# 1  https://docs.oracle.com/javase/tutorial/2d/ind...
# 2  https://docs.oracle.com/javase/tutorial/2d/adv...
# 3  https://docs.oracle.com/javase/tutorial/2d/adv...
# 4  https://docs.oracle.com/javase/tutorial/2d/adv...

# %%
df.iloc[1000].text
# Out:
# 'You use the JAR Signing and Verification Tool to sign JAR files and time stamp the signature. You invoke the JAR Signing and Verification Tool by using the jarsigner command, so we\'ll refer to it as "Jarsigner" for short.  To sign a JAR file, you must first have a private key. Private keys and their associated public-key certificates are stored in password-protected databases called keystores . A keystore can hold the keys of many potential signers. Each key in the keystore can be identified by an alias which is typically the name of the signer who owns the key. The key belonging to Rita Jones might have the alias "rita", for example.  The basic form of the command for signing a JAR file is  jarsigner jar-file alias   In this command:   jar-file is the pathname of the JAR file that\'s to be signed.  alias is the alias identifying the private key that\'s to be used to sign the JAR file, and the key\'s associated certificate.   The Jarsigner tool will prompt you for the passwords for the keystore and alias.  This basic form of the command assumes that the keystore to be used is in a file named .keystore in your home directory. It will create signature and signature block files with names x.SF and x.DSA respectively, where x is the first eight letters of the alias, all converted to upper case. This basic command will overwrite the original JAR file with the signed JAR file.  In practice, you might want to use one or more of the command options that are available. For example, time stamping the signature is encouraged so that any tool used to deploy your application can verify that the certificate used to sign the JAR file was valid at the time that the file was signed. A warning is issued by the Jarsigner tool if a time stamp is not included.  Options precede the jar-file pathname. The following table describes the options that are available:    Jarsigner Command Options   Option  Description    -keystore  url  Specifies a keystore to be used if you don\'t want to use the .keystore default database.    -sigfile  file  Specifies the base name for the .SF and .DSA files if you don\'t want the base name to be taken from your alias. file must be composed only of upper case letters (A-Z), numerals (0-9), hyphen (-), and underscore (_).    -signedjar  file  Specifies the name of the signed JAR file to be generated if you don\'t want the original unsigned file to be overwritten with the signed file.    -tsa  url  Generates a time stamp for the signature using the Time Stamping Authority (TSA) identified by the URL.    -tsacert  alias  Generates a time stamp for the signature using the TSA\'s public key certificate identified by alias .    -altsigner  class  Indicates that an alternative signing mechanism be used to time stamp the signature. The fully-qualified class name identifies the class used.    -altsignerpath  classpathlist  Provides the path to the class identified by the altsigner option and any JAR files that the class depends on.    Example  Let\'s look at a couple of examples of signing a JAR file with the Jarsigner tool. In these examples, we will assume the following:   Your alias is "johndoe".  The keystore you want to use is in a file named "mykeys" in the current working directory.  The TSA that you want to use to time stamp the signature is located at http://tsa.url.example.com .   Under these assumptions, you could use this command to sign a JAR file named app.jar :  jarsigner -keystore mykeys -tsa http://tsa.url.example.com app.jar johndoe  You will be prompted to enter the passwords for both the keystore and your alias. Because this command doesn\'t make use of the -sigfile option, the .SF and .DSA files it creates would be named JOHNDOE.SF and JOHNDOE.DSA . Because the command doesn\'t use the -signedjar option, the resulting signed file will overwrite the original version of app.jar .  Let\'s look at what would happen if you used a different combination of options:  jarsigner -keystore mykeys -sigfile SIG -signed ...

# %%
import urllib2
import re
import re
from bs4 import BeautifulSoup
import json
import datetime
from dateutil.parser import parse
from bs4.element import Comment
import pandas as pd

def remove_spaces(text):
    return re.sub('\s+',' ',text)
oracle_url = 'https://docs.oracle.com/javase/tutorial/'

def get_all_links(oracle_url):
    page = urllib2.urlopen(oracle_url)
    soup = BeautifulSoup(page)
    ul = soup.find_all('ul', class_="BlueArrows")
    
    domain = "https://docs.oracle.com/javase/tutorial/%s"
    links = []
    for u in ul:
        li = u.find_all('li')
        for l in li:
            a_tag = l.find('a')
            if a_tag:
                href = a_tag.get('href')
                title = a_tag.text
                if 'http' in href:
                    links.append((title, href))
                else:
                    links.append((title, domain%href))
    return links

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

def get_links_text(all_links):
    url_list = []
    url_list.extend(all_links)

    result = []
    domain = "https://docs.oracle.com/javase/tutorial/%s"
    url_set = set()
    while url_list:
        title, url, depth = url_list.pop()
        url_set.add(url)
        if depth > 6:
            continue
        try:
            page = urllib2.urlopen(url)
        except:
            continue

        soup = BeautifulSoup(page)
        body = soup.find('div', {"id":"PageContent"})
        if body:
            d = {}
            d["url"] = url
            d["title"] = title
            d["text"] = text_from_html(str(body)).encode('utf-8').strip()
            result.append(d)

            a_tags = body.find_all('a')
            for tag in a_tags:
                href = tag.get('href')
                text = tag.text
                if not href:
                    continue
                if 'http' in href:
                    href_url = href
                else:
                    href_url = url.replace('index.html', href)
                if href_url not in url_set and 'docs.oracle.com' in href_url:
                    url_list.append((text, href_url, depth+1))
    return result

links = get_all_links(oracle_url)
all_links = [(title, link, 0) for title, link in links]
result = get_links_text(all_links)

# %%
len(result)
# Out:
# 2550

# %%
df = pd.DataFrame(result)

# %%
df.head()
# Out:
#                                                 text  \
# 0  The Sockets Direct Protocol (SDP) provides acc...
# 1  This trail introduces you to the Java 2Dâ„¢ AP...
# 2  This lesson shows you how to use Graphics2D to...
# 3  To enable the user to interact with the graphi...
# 4  Constructive area geometry (CAG) is the proces...
#
#                                                title  \
# 0                            Sockets Direct Protocol
# 1                                        2D Graphics
# 2                         Advanced topics in Java 2D
# 3                        Supporting User Interaction
# 4  Constructing Complex Shapes from Geometry Prim...
#
#                                                  url
# 0  https://docs.oracle.com/javase/tutorial/sdp/in...
# 1  https://docs.oracle.com/javase/tutorial/2d/ind...
# 2  https://docs.oracle.com/javase/tutorial/2d/adv...
# 3  https://docs.oracle.com/javase/tutorial/2d/adv...
# 4  https://docs.oracle.com/javase/tutorial/2d/adv...

# %%
df.to_csv('oracleTM.csv',encoding = 'utf-8')

# %%
def is_not_ascii(string):
    return string is not None and any([ord(s) >= 128 for s in string])

df[df['text'].apply(is_not_ascii)]
# Out:
#                                                    text  \
# 1     This trail introduces you to the Java 2Dâ„¢ AP...
# 4     Constructive area geometry (CAG) is the proces...
# 5     Use the Graphics2D class rendering hints attri...
# 6     The AlphaComposite class encapsulates various ...
# 8     You can modify the transform attribute in the ...
# 9     Since the Java 2D API enables you to draw on a...
# 11    Another common printing task is to print the c...
# 14    Traditionally, the user wants to see the page ...
# 15    This section explains how to create a basic pr...
# 17    This lesson started with an explanation for us...
# 20    When you think of digital images, you probably...
# 22    This lesson introduces you to the concept of w...
# 25    There are two types of fonts: physical fonts a...
# 27    You already know how to create different geome...
# 28    You have already learned how to draw most of s...
# 29    The Java 2D API provides several classes that ...
# 30    The Java 2D API is powerful and complex. Howev...
# 31    A JSlider component is intended to let the use...
# 32    The Java 2D API maintains two coordinate space...
# 35    Constructive area geometry (CAG) is the proces...
# 36    Use the Graphics2D class rendering hints attri...
# 37    The AlphaComposite class encapsulates various ...
# 39    You can modify the transform attribute in the ...
# 41    All of the Swing and Java 2D graphics, includi...
# 43    The Java 2D API has various text rendering cap...
# 44    The Java 2D API provides a useful set of stand...
# 45    The Java 2D API provides a uniform rendering m...
# 46    The Java 2D API maintains two coordinate space...
# 47    The Java 2D API maintains two coordinate space...
# 48    The Java Sound API is a low-level API for effe...
# ...                                                 ...
# 2495  Consider writing a method that takes an array ...
# 2501  Strings, which are widely used in Java program...
# 2503  Interfaces  You saw an example of implementing...
# 2504  In the preceding \nlessons,\n you have seen in...
# 2505  There are a number of situations in software e...
# 2506  Annotations , a form of metadata, provide data...
# 2508  An enum type is a special data type that enabl...
# 2517  As you learned in the previous lesson, an obje...
# 2521  As you've already learned, objects define thei...
# 2524  Objects are key to understanding object-orient...
# 2525  This trail provides everything you'll need to ...
# 2527  Now that you've seen the "Hello World!" applic...
# 2528  Now that you've seen the "Hello World!" applic...
# 2529  Now that you've seen the "Hello World!" applic...
# 2530  Now that you've seen the "Hello World!" applic...
# 2531  Now that you've seen the "Hello World!" applic...
# 2532  Now that you've seen the "Hello World!" applic...
# 2533  Now that you've seen the "Hello World!" applic...
# 2534  Now that you've seen the "Hello World!" applic...
# 2535  Now that you've seen the "Hello World!" applic...
# 2538  Now that you've seen the "Hello World!" applic...
# 2539  Now that you've seen the "Hello World!" applic...
# 2540  Now that you've seen the "Hello World!" applic...
# 2541  Now that you've seen the "Hello World!" applic...
# 2542  Now that you've seen the "Hello World!" applic...
# 2543  It's time to write your first application! The...
# 2544  It's time to write your first application! The...
# 2545  It's time to write your first application! The...
# 2547  We can't promise you fame, fortune, or even a ...
# 2549  Java technology is both a programming language...
#
#                                                   title  \
# 1                                           2D Graphics
# 4     Constructing Complex Shapes from Geometry Prim...
# 5                         Controlling Rendering Quality
# 6                                  Compositing Graphics
# 8                 Transforming Shapes, Text, and Images
# 9                                              Printing
# 11            Printing the Contents of a User Interface
# 14                            Using Print Setup Dialogs
# 15                             A Basic Printing Program
# 17                              Writing/saving an image
# 20                             Reading/Loading an image
# 22                               Working with Text APIs
# 25                           Physical and Logical Fonts
# 27                                 Filling and Stroking
# 28                             Drawing Arbitrary Shapes
# 29                         Drawing Geometric Primitives
# 30                        Getting started with Graphics
# 31                                   How to Use Sliders
# 32                                          coordinates
# 35    Constructing Complex Shapes from Geometry Prim...
# 36                        Controlling Rendering Quality
# 37                                 Compositing Graphics
# 39                Transforming Shapes, Text, and Images
# 41                                             Printing
# 43                                                 Text
# 44                                 Geometric Primitives
# 45                                    Java 2D Rendering
# 46                             device space coordinates
# 47                                           user space
# 48                                                Sound
# ...                                                 ...
# 2495                                    Generic Methods
# 2501                                            Strings
# 2503                         Interfaces and Inheritance
# 2504                                        Inheritance
# 2505                                         Interfaces
# 2506                                        Annotations
# 2508                                         Enum Types
# 2517                                          Variables
# 2521                              What Is an Interface?
# 2524                                 What Is an Object?
# 2525                                    Getting Started
# 2527    A Closer Look at the "Hello World!" Application
# 2528                                    the main method
# 2529                 the HelloWorldApp class definition
# 2530                               source code comments
# 2531    A Closer Look at the "Hello World!" Application
# 2532                    A Closer Look at "Hello World!"
# 2533                                    the main method
# 2534                 the HelloWorldApp class definition
# 2535                               source code comments
# 2538    A Closer Look at the "Hello World!" Application
# 2539                                    the main method
# 2540                 the HelloWorldApp class definition
# 2541                               source code comments
# 2542    A Closer Look at the "Hello World!" Application
# 2543            "Hello World!" for Solaris OS and Linux
# 2544               "Hello World!" for Microsoft Windows
# 2545                "Hello World!" for the NetBeans IDE
# 2547           How Will Java Technology Change My Life?
# 2549                          About the Java Technology
#
#                                                     url
# 1     https://docs.oracle.com/javase/tutorial/2d/ind...
# 4     https://docs.oracle.com/javase/tutorial/2d/adv...
# 5     https://docs.oracle.com/javase/tutorial/2d/adv...
# 6     https://docs.oracle.com/javase/tutorial/2d/adv...
# 8     https://docs.oracle.com/javase/tutorial/2d/adv...
# 9     https://docs.oracle.com/javase/tutorial/2d/pri...
# 11    https://docs.oracle.com/javase/tutorial/2d/pri...
# 14    https://docs.oracle.com/javase/tutorial/2d/pri...
# 15    https://docs.oracle.com/javase/tutorial/2d/pri...
# 17    https://docs.oracle.com/javase/tutorial/2d/ima...
# 20    https://docs.oracle.com/javase/tutorial/2d/ima...
# 22    https://docs.oracle.com/javase/tutorial/2d/tex...
# 25    https://docs.oracle.com/javase/tutorial/2d/tex...
# 27    https://docs.oracle.com/javase/tutorial/2d/geo...
# 28    https://docs.oracle.com/javase/tutorial/2d/geo...
# 29    https://docs.oracle.com/javase/tutorial/2d/geo...
# 30    https://docs.oracle.com/javase/tutorial/2d/bas...
# 31    https://docs.oracle.com/javase/tutorial/2d/bas...
# 32    https://docs.oracle.com/javase/tutorial/2d/bas...
# 35    https://docs.oracle.com/javase/tutorial/2d/bas...
# 36    https://docs.oracle.com/javase/tutorial/2d/bas...
# 37    https://docs.oracle.com/javase/tutorial/2d/bas...
# 39    https://docs.oracle.com/javase/tutorial/2d/bas...
# 41    https://docs.oracle.com/javase/tutorial/2d/ove...
# 43    https://docs.oracle.com/javase/tutorial/2d/ove...
# 44    https://docs.oracle.com/javase/tutorial/2d/ove...
# 45    https://docs.oracle.com/javase/tutorial/2d/ove...
# 46    https://docs.oracle.com/javase/tutorial/2d/ove...
# 47    https://docs.oracle.com/javase/tutorial/2d/ove...
# 48    https://docs.oracle.com/javase/tutorial/sound/...
# ...                                                 ...
# 2495  https://docs.oracle.com/javase/tutorial/java/g...
# 2501  https://docs.oracle.com/javase/tutorial/java/d...
# 2503  https://docs.oracle.com/javase/tutorial/java/I...
# 2504  https://docs.oracle.com/javase/tutorial/java/I...
# 2505  https://docs.oracle.com/javase/tutorial/java/I...
# 2506  https://docs.oracle.com/javase/tutorial/java/a...
# 2508  https://docs.oracle.com/javase/tutorial/java/j...
# 2517  https://docs.oracle.com/javase/tutorial/java/n...
# 2521  https://docs.oracle.com/javase/tutorial/java/c...
# 2524  https://docs.oracle.com/javase/tutorial/java/c...
# 2525  https://docs.oracle.com/javase/tutorial/getSta...
# 2527  https://docs.oracle.com/javase/tutorial/getSta...
# 2528  https://docs.oracle.com/javase/tutorial/getSta...
# 2529  https://docs.oracle.com/javase/tutorial/getSta...
# 2530  https://docs.oracle.com/javase/tutorial/getSta...
# 2531  https://docs.oracle.com/javase/tutorial/getSta...
# 2532  https://docs.oracle.com/javase/tutorial/getSta...
# 2533  https://docs.oracle.com/javase/tutorial/getSta...
# 2534  https://docs.oracle.com/javase/tutorial/getSta...
# 2535  https://docs.oracle.com/javase/tutorial/getSta...
# 2538  https://docs.oracle.com/javase/tutorial/getSta...
# 2539  https://docs.oracle.com/javase/tutorial/getSta...
# 2540  https://docs.oracle.com/javase/tutorial/getSta...
# 2541  https://docs.oracle.com/javase/tutorial/getSta...
# 2542  https://docs.oracle.com/javase/tutorial/getSta...
# 2543  https://docs.oracle.com/javase/tutorial/getSta...
# 2544  https://docs.oracle.com/javase/tutorial/getSta...
# 2545  https://docs.oracle.com/javase/tutorial/getSta...
# 2547  https://docs.oracle.com/javase/tutorial/getSta...
# 2549  https://docs.oracle.com/javase/tutorial/getSta...
#
# [892 rows x 3 columns]

# %%
df
# Out:
#                                                    text  \
# 0     The Sockets Direct Protocol (SDP) provides acc...
# 1     This trail introduces you to the Java 2Dâ„¢ AP...
# 2     This lesson shows you how to use Graphics2D to...
# 3     To enable the user to interact with the graphi...
# 4     Constructive area geometry (CAG) is the proces...
# 5     Use the Graphics2D class rendering hints attri...
# 6     The AlphaComposite class encapsulates various ...
# 7     Any Shape object can be used as a clipping pat...
# 8     You can modify the transform attribute in the ...
# 9     Since the Java 2D API enables you to draw on a...
# 10    The PrintUIWindow.java example represented in ...
# 11    Another common printing task is to print the c...
# 12    From the previous lessons you have learned tha...
# 13    You have already learned how to use the Printa...
# 14    Traditionally, the user wants to see the page ...
# 15    This section explains how to create a basic pr...
# 16    As you have already learned from the Images le...
# 17    This lesson started with an explanation for us...
# 18    We already know how to load an existing image,...
# 19    As you have already learned, the Graphics.draw...
# 20    When you think of digital images, you probably...
# 21    In the Java 2D API an image is typically a rec...
# 22    This lesson introduces you to the concept of w...
# 23    The Java 2D API provides mechanisms to support...
# 24    To properly measure text, you need to learn a ...
# 25    There are two types of fonts: physical fonts a...
# 26    In prior lessons, you have learned the graphic...
# 27    You already know how to create different geome...
# 28    You have already learned how to draw most of s...
# 29    The Java 2D API provides several classes that ...
# ...                                                 ...
# 2520  A package is a namespace that organizes a set ...
# 2521  As you've already learned, objects define thei...
# 2522  Different kinds of objects often have a certai...
# 2523  In the real world, you'll often find many indi...
# 2524  Objects are key to understanding object-orient...
# 2525  This trail provides everything you'll need to ...
# 2526  Compiler Problems  Common Error Messages on Mi...
# 2527  Now that you've seen the "Hello World!" applic...
# 2528  Now that you've seen the "Hello World!" applic...
# 2529  Now that you've seen the "Hello World!" applic...
# 2530  Now that you've seen the "Hello World!" applic...
# 2531  Now that you've seen the "Hello World!" applic...
# 2532  Now that you've seen the "Hello World!" applic...
# 2533  Now that you've seen the "Hello World!" applic...
# 2534  Now that you've seen the "Hello World!" applic...
# 2535  Now that you've seen the "Hello World!" applic...
# 2536  The sections listed below provide detailed ins...
# 2537  Compiler Problems  Common Error Messages on Mi...
# 2538  Now that you've seen the "Hello World!" applic...
# 2539  Now that you've seen the "Hello World!" applic...
# 2540  Now that you've seen the "Hello World!" applic...
# 2541  Now that you've seen the "Hello World!" applic...
# 2542  Now that you've seen the "Hello World!" applic...
# 2543  It's time to write your first application! The...
# 2544  It's time to write your first application! The...
# 2545  It's time to write your first application! The...
# 2546  Talk about Java technology seems to be everywh...
# 2547  We can't promise you fame, fortune, or even a ...
# 2548  The general-purpose, high-level Java programmi...
# 2549  Java technology is both a programming language...
#
#                                                   title  \
# 0                               Sockets Direct Protocol
# 1                                           2D Graphics
# 2                            Advanced topics in Java 2D
# 3                           Supporting User Interaction
# 4     Constructing Complex Shapes from Geometry Prim...
# 5                         Controlling Rendering Quality
# 6                                  Compositing Graphics
# 7                           Clipping the Drawing Region
# 8                 Transforming Shapes, Text, and Images
# 9                                              Printing
# 10                 Printing Support in Swing Components
# 11            Printing the Contents of a User Interface
# 12           Working with Print Services and Attributes
# 13                    Printing a Multiple Page Document
# 14                            Using Print Setup Dialogs
# 15                             A Basic Printing Program
# 16                                  Working with Images
# 17                              Writing/saving an image
# 18                     Creating and drawing To an image
# 19                                     Drawing an image
# 20                             Reading/Loading an image
# 21                                               Images
# 22                               Working with Text APIs
# 23                                Advanced Text Display
# 24                                       Measuring Text
# 25                           Physical and Logical Fonts
# 26                                Working with Geometry
# 27                                 Filling and Stroking
# 28                             Drawing Arbitrary Shapes
# 29                         Drawing Geometric Primitives
# ...                                                 ...
# 2520                                 What Is a Package?
# 2521                              What Is an Interface?
# 2522                               What Is Inheritance?
# 2523                                   What Is a Class?
# 2524                                 What Is an Object?
# 2525                                    Getting Started
# 2526              Common Problems (and Their Solutions)
# 2527    A Closer Look at the "Hello World!" Application
# 2528                                    the main method
# 2529                 the HelloWorldApp class definition
# 2530                               source code comments
# 2531    A Closer Look at the "Hello World!" Application
# 2532                    A Closer Look at "Hello World!"
# 2533                                    the main method
# 2534                 the HelloWorldApp class definition
# 2535                               source code comments
# 2536                     The "Hello World!" Application
# 2537              Common Problems (and Their Solutions)
# 2538    A Closer Look at the "Hello World!" Application
# 2539                                    the main method
# 2540                 the HelloWorldApp class definition
# 2541                               source code comments
# 2542    A Closer Look at the "Hello World!" Application
# 2543            "Hello World!" for Solaris OS and Linux
# 2544               "Hello World!" for Microsoft Windows
# 2545                "Hello World!" for the NetBeans IDE
# 2546                     The Java Technology Phenomenon
# 2547           How Will Java Technology Change My Life?
# 2548                       What Can Java Technology Do?
# 2549                          About the Java Technology
#
#                                                     url
# 0     https://docs.oracle.com/javase/tutorial/sdp/in...
# 1     https://docs.oracle.com/javase/tutorial/2d/ind...
# 2     https://docs.oracle.com/javase/tutorial/2d/adv...
# 3     https://docs.oracle.com/javase/tutorial/2d/adv...
# 4     https://docs.oracle.com/javase/tutorial/2d/adv...
# 5     https://docs.oracle.com/javase/tutorial/2d/adv...
# 6     https://docs.oracle.com/javase/tutorial/2d/adv...
# 7     https://docs.oracle.com/javase/tutorial/2d/adv...
# 8     https://docs.oracle.com/javase/tutorial/2d/adv...
# 9     https://docs.oracle.com/javase/tutorial/2d/pri...
# 10    https://docs.oracle.com/javase/tutorial/2d/pri...
# 11    https://docs.oracle.com/javase/tutorial/2d/pri...
# 12    https://docs.oracle.com/javase/tutorial/2d/pri...
# 13    https://docs.oracle.com/javase/tutorial/2d/pri...
# 14    https://docs.oracle.com/javase/tutorial/2d/pri...
# 15    https://docs.oracle.com/javase/tutorial/2d/pri...
# 16    https://docs.oracle.com/javase/tutorial/2d/ima...
# 17    https://docs.oracle.com/javase/tutorial/2d/ima...
# 18    https://docs.oracle.com/javase/tutorial/2d/ima...
# 19    https://docs.oracle.com/javase/tutorial/2d/ima...
# 20    https://docs.oracle.com/javase/tutorial/2d/ima...
# 21    https://docs.oracle.com/javase/tutorial/2d/ima...
# 22    https://docs.oracle.com/javase/tutorial/2d/tex...
# 23    https://docs.oracle.com/javase/tutorial/2d/tex...
# 24    https://docs.oracle.com/javase/tutorial/2d/tex...
# 25    https://docs.oracle.com/javase/tutorial/2d/tex...
# 26    https://docs.oracle.com/javase/tutorial/2d/geo...
# 27    https://docs.oracle.com/javase/tutorial/2d/geo...
# 28    https://docs.oracle.com/javase/tutorial/2d/geo...
# 29    https://docs.oracle.com/javase/tutorial/2d/geo...
# ...                                                 ...
# 2520  https://docs.oracle.com/javase/tutorial/java/c...
# 2521  https://docs.oracle.com/javase/tutorial/java/c...
# 2522  https://docs.oracle.com/javase/tutorial/java/c...
# 2523  https://docs.oracle.com/javase/tutorial/java/c...
# 2524  https://docs.oracle.com/javase/tutorial/java/c...
# 2525  https://docs.oracle.com/javase/tutorial/getSta...
# 2526  https://docs.oracle.com/javase/tutorial/getSta...
# 2527  https://docs.oracle.com/javase/tutorial/getSta...
# 2528  https://docs.oracle.com/javase/tutorial/getSta...
# 2529  https://docs.oracle.com/javase/tutorial/getSta...
# 2530  https://docs.oracle.com/javase/tutorial/getSta...
# 2531  https://docs.oracle.com/javase/tutorial/getSta...
# 2532  https://docs.oracle.com/javase/tutorial/getSta...
# 2533  https://docs.oracle.com/javase/tutorial/getSta...
# 2534  https://docs.oracle.com/javase/tutorial/getSta...
# 2535  https://docs.oracle.com/javase/tutorial/getSta...
# 2536  https://docs.oracle.com/javase/tutorial/getSta...
# 2537  https://docs.oracle.com/javase/tutorial/getSta...
# 2538  https://docs.oracle.com/javase/tutorial/getSta...
# 2539  https://docs.oracle.com/javase/tutorial/getSta...
# 2540  https://docs.oracle.com/javase/tutorial/getSta...
# 2541  https://docs.oracle.com/javase/tutorial/getSta...
# 2542  https://docs.oracle.com/javase/tutorial/getSta...
# 2543  https://docs.oracle.com/javase/tutorial/getSta...
# 2544  https://docs.oracle.com/javase/tutorial/getSta...
# 2545  https://docs.oracle.com/javase/tutorial/getSta...
# 2546  https://docs.oracle.com/javase/tutorial/getSta...
# 2547  https://docs.oracle.com/javase/tutorial/getSta...
# 2548  https://docs.oracle.com/javase/tutorial/getSta...
# 2549  https://docs.oracle.com/javase/tutorial/getSta...
#
# [2550 rows x 3 columns]
